# %% [markdown]
# # 🌳 Trees
# The trees data ranks each neighborhood by how beneficial its trees are (in dollar value) to four different factors:
# - Stormwater Benefits
# - Property Value
# - Electricity Benefits
# - Air Quality Value

# %%
import pandas as pd
import numpy as np

# %%
#import data from csv
t = pd.read_csv("data/trees_data.csv")
trees = t.iloc[:,[48,3,15,16,17,19,20,37,38,39,47]].dropna().sort_values("neighborhood") #isolate just the columns I care about into one dataframe.
trees.head(10)
# Out:
# C:\Users\hunte\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#            neighborhood             common_name  \
# 32072  Allegheny Center                  Ginkgo
# 32340  Allegheny Center                Oak: Pin
# 32339  Allegheny Center                Oak: Pin
# 32338  Allegheny Center                Oak: Pin
# 32337  Allegheny Center  Honeylocust: Thornless
# 32336  Allegheny Center           Maple: Norway
# 32335  Allegheny Center           Maple: Norway
# 32333  Allegheny Center           Maple: Norway
# 32332  Allegheny Center      Sycamore: American
# 32331  Allegheny Center        Linden: American
#
#        stormwater_benefits_dollar_value  stormwater_benefits_runoff_elim  \
# 32072                         12.683000                      1585.374960
# 32340                         22.067105                      2758.388097
# 32339                          6.699391                       837.423843
# 32338                          6.699391                       837.423843
# 32337                         24.245188                      3030.648510
# 32336                         15.141617                      1892.702165
# 32335                         12.134547                      1516.818404
# 32333                          8.317154                      1039.644231
# 32332                         39.447369                      4930.921139
# 32331                         35.001493                      4375.186618
#
#        property_value_benefits_dollarvalue  \
# 32072                            58.142100
# 32340                            90.736693
# 32339                            57.028955
# 32338                            57.028955
# 32337                           118.394322
# 32336                            84.564162
# 32335                            69.909141
# 32333                            65.024134
# 32332                            95.708800
# 32331                            21.556700
#
#        energy_benefits_electricity_dollar_value  \
# 32072                                 13.999165
# 32340                                 20.543994
# 32339                                  7.162698
# 32338                                  7.162698
# 32337                                 21.801985
# 32336                                 16.514168
# 32335                                 15.024900
# 32333                                 14.528478
# 32332                                 30.453530
# 32331                                 25.769106
#
#        energy_benefits_gas_dollar_value  \
# 32072                         52.862601
# 32340                         69.790648
# 32339                         26.686144
# 32338                         26.686144
# 32337                         78.366246
# 32336                         63.117320
# 32335                         54.867465
# 32333                         52.117514
# 32332                         99.004583
# 32331                         86.216872
#
#        air_quality_benfits_total_dollar_value  air_quality_benfits_total_lbs  \
# 32072                               11.274586                       2.350492
# 32340                               15.608748                       3.203296
# 32339                                5.041264                       1.045038
# 32338                                5.041264                       1.045038
# 32337                               16.406774                       3.376422
# 32336                               12.412174                       2.558153
# 32335                               10.686449                       2.213377
# 32333                                6.483089                       1.317777
# 32332                               26.696681                       5.500751
# 32331                               19.290425                       3.966550
#
#        co2_benefits_dollar_value  overall_benefits_dollar_value
# 32072                   1.387450                     150.348902
# 32340                   2.285870                     221.033059
# 32339                   0.750016                     103.368467
# 32338                   0.750016                     103.368467
# 32337                   1.721132                     260.935647
# 32336                   2.173950                     193.923392
# 32335                   1.734513                     164.357015
# 32333                   0.968313                     147.438681
# 32332                   3.338626                     294.649589
# 32331                   1.469043                     189.303639

# %%
#How many trees are in each neighborhood?
treesPerNeighborhood = {}

for r in range(len(trees)) :
    neighborhood = trees.iloc[r,0]
    
    try :
        treesPerNeighborhood[neighborhood] += 1
    except :
        treesPerNeighborhood[neighborhood] = 1
        
#for x in treesPerNeighborhood :
#    print(str(x) + " " + str(treesPerNeighborhood[x]))

# %%
#Isolate each unique neighborhood
n = trees["neighborhood"].unique().tolist()

#change neighborhood column in dataframe to the indicies
for thing in n :
    trees = trees.replace([thing], n.index(thing))

# %%
#Function to collect all of the values in a certain column for each neighborhood.
def statsGrab(c, df) :
    statList = []
    stat = 0
    index = 0
    for r in range (len(df)) :
        if (df.iloc[r,0] == index) :
            stat += float(df.iloc[r,c])
        else :
            statList.append(stat)
            index+=1
            stat = float(df.iloc[r,c])
    statList.append(stat)
    return statList

stormValue = statsGrab(2, trees) #Isolate column 2 with storm value dollar benefits
propValue = statsGrab(4, trees) #Isolate column 4 with property value benefits
elecValue = statsGrab(5, trees) #Isolate column 5 with electricity value benefits
airValue = statsGrab(7, trees) #Isolates column 7 with air quality value benefits

# %%
#the data is in the wrong orientation for a dataframe. Time to rework it...
index = []
scoresList = [[]]
for i in range(90) :  
    index.append(i)
    
    scoresList[i].append(n[i])
    scoresList[i].append(stormValue[i])
    scoresList[i].append(propValue[i])
    scoresList[i].append(elecValue[i])
    scoresList[i].append(airValue[i])
    
    scoresList.insert(i+1, [])
    
del scoresList[90]
    
scores = pd.DataFrame(scoresList,
                      columns = ['Neighborhood', 'Stormwater Benefits', 'Property Value', 'Electric Benefits', 'Air Quality Benefits'], index=index)

scores
# Out:
#            Neighborhood  Stormwater Benefits  Property Value  \
# 0      Allegheny Center         15178.511842    57963.126001
# 1        Allegheny West          5365.137916    22959.330812
# 2             Allentown           526.717770     3318.198878
# 3             Arlington           389.313250     2666.422788
# 4     Arlington Heights            79.176047      330.289204
# ..                  ...                  ...             ...
# 85  Upper Lawrenceville          2191.535869    19677.196016
# 86             West End           525.474322     5434.736234
# 87         West Oakland           235.535630     3312.210640
# 88             Westwood          3058.061442    12383.676820
# 89              Windgap          1215.133689     5637.833228
#
#     Electric Benefits  Air Quality Benefits
# 0        14193.463380          10723.002809
# 1         5022.063352           3764.227070
# 2          622.094573            427.768002
# 3          498.892450            301.765273
# 4           92.492976             43.677589
# ..                ...                   ...
# 85        2474.420848           1831.984740
# 86         555.482402            434.194246
# 87         322.171889            196.237780
# 88        3131.185839           1936.210446
# 89        1316.696577            880.050485
#
# [90 rows x 5 columns]

# %% [markdown]
# # Let's look at the data!
#
# Below are 5 charts, one combining all of the metrics, and one for each of the 4 metrics pulled from this data set to measure neighborhood quality. After reviewing the data, we can numerically sort and "place" each neighborhood. These placements will be added up, and the neighborhood with the lowest score will win!

# %% [markdown]
# ## Benefits in all areas

# %%
scores.plot.bar(x='Neighborhood', figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='Neighborhood'>

# %% [markdown]
# ## Stormwater Benefits

# %%
scores.iloc[:,[0,1]].plot.bar(x="Neighborhood", figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='Neighborhood'>

# %% [markdown]
# ## Property Value Benefits

# %%
scores.iloc[:,[0,2]].plot.bar(x='Neighborhood', figsize=(20,8), color='orange')
# Out:
# <AxesSubplot:xlabel='Neighborhood'>

# %% [markdown]
# ## Electricity Benefits

# %%
scores.iloc[:,[0,3]].plot.bar(x='Neighborhood', figsize=(20,8), color='green')
# Out:
# <AxesSubplot:xlabel='Neighborhood'>

# %% [markdown]
# ## Air Quality Benefits

# %%
scores.iloc[:,[0,4]].plot.bar(x='Neighborhood', figsize=(20,8), color='red')
# Out:
# <AxesSubplot:xlabel='Neighborhood'>

# %% [markdown]
# ## Data Reflection
# The shape of these graphs are all fairly similar, and it is obvious that the same neighborhoods are coming out on top in each area. But let's rank them and total it all up to see which one wins!

# %% [markdown]
# # The Ranking

# %%
stormRank = []
propRank = []
elecRank = []
airRank = []

for r in range(90) :
    stormRank.append(0)
    propRank.append(0)
    elecRank.append(0)
    airRank.append(0)

#sort each of the sheets by the values (lowest to highest)
sScores = scores.sort_values("Stormwater Benefits")
pScores = scores.sort_values("Property Value")
eScores = scores.sort_values("Electric Benefits")
aScores = scores.sort_values("Air Quality Benefits")

for r in range(90) : #assign ranks with 90 at the lowest and 1 at the highest dollar value
    i = sScores.index.tolist()
    stormRank[i[r]] = (90-r)
    
    i = pScores.index.tolist()
    propRank[i[r]] = (90-r)
    
    i = eScores.index.tolist()
    elecRank[i[r]] = (90-r)
    
    i = aScores.index.tolist()
    airRank[i[r]] = (90-r)

# %%
#Once again, the data is in the wrong orientation for a dataframe, but I want to plot it before determining final scores.
index = []
scoresList = [[]]
for i in range(90) :  
    index.append(i)
    
    scoresList[i].append(n[i])
    scoresList[i].append(stormRank[i])
    scoresList[i].append(propRank[i])
    scoresList[i].append(elecRank[i])
    scoresList[i].append(airRank[i])
    
    scoresList.insert(i+1, [])
    
del scoresList[90]
    
rank = pd.DataFrame(scoresList,
                      columns = ['Neighborhood', 'Stormwater Rank', 'Property Rank', 'Electric Rank', 'Air Quality Rank'], index=index)

rank
# Out:
#            Neighborhood  Stormwater Rank  Property Rank  Electric Rank  \
# 0      Allegheny Center                5              8              6
# 1        Allegheny West               20             32             25
# 2             Allentown               73             75             71
# 3             Arlington               77             77             77
# 4     Arlington Heights               84             85             84
# ..                  ...              ...            ...            ...
# 85  Upper Lawrenceville               46             36             48
# 86             West End               74             65             75
# 87         West Oakland               80             76             81
# 88             Westwood               35             54             37
# 89              Windgap               56             63             58
#
#     Air Quality Rank
# 0                  5
# 1                 21
# 2                 72
# 3                 77
# 4                 84
# ..               ...
# 85                44
# 86                71
# 87                79
# 88                39
# 89                58
#
# [90 rows x 5 columns]

# %% [markdown]
# Here's how each neighborhood ranks! The smaller the bar, the better the rank.

# %%
rank.plot.bar(x='Neighborhood', figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='Neighborhood'>

# %% [markdown]
# Let's look at the individual top ten!

# %% [markdown]
# ## Stormwater Rank

# %%
rank.iloc[:,[0,1]].sort_values("Stormwater Rank").head(10)
# Out:
#            Neighborhood  Stormwater Rank
# 76  Squirrel Hill South                1
# 39        Highland Park                2
# 75  Squirrel Hill North                3
# 62         Point Breeze                4
# 0      Allegheny Center                5
# 67            Shadyside                6
# 60          Perry North                7
# 78      Stanton Heights                8
# 13            Brookline                9
# 12     Brighton Heights               10

# %% [markdown]
# ## Property Value Rank

# %%
rank.iloc[:,[0,2]].sort_values("Property Rank").head(10)
# Out:
#                  Neighborhood  Property Rank
# 76        Squirrel Hill South              1
# 39              Highland Park              2
# 75        Squirrel Hill North              3
# 67                  Shadyside              4
# 71           South Side Flats              5
# 62               Point Breeze              6
# 9                  Bloomfield              7
# 0            Allegheny Center              8
# 60                Perry North              9
# 16  Central Business District             10

# %% [markdown]
# ## Electric Benefit Rank

# %%
rank.iloc[:,[0,3]].sort_values("Electric Rank").head(10)
# Out:
#            Neighborhood  Electric Rank
# 76  Squirrel Hill South              1
# 39        Highland Park              2
# 75  Squirrel Hill North              3
# 62         Point Breeze              4
# 67            Shadyside              5
# 0      Allegheny Center              6
# 60          Perry North              7
# 78      Stanton Heights              8
# 9            Bloomfield              9
# 12     Brighton Heights             10

# %% [markdown]
# ## Air Quality Benefit Rank

# %%
rank.iloc[:,[0,4]].sort_values("Air Quality Rank").head(10)
# Out:
#            Neighborhood  Air Quality Rank
# 76  Squirrel Hill South                 1
# 39        Highland Park                 2
# 75  Squirrel Hill North                 3
# 62         Point Breeze                 4
# 0      Allegheny Center                 5
# 67            Shadyside                 6
# 60          Perry North                 7
# 78      Stanton Heights                 8
# 9            Bloomfield                 9
# 13            Brookline                10

# %% [markdown]
# Now, to add up the scores!

# %%
nRank = []
for r in range(90) :
    rankSum = stormRank[r] + propRank[r] + elecRank[r] + airRank[r]
    nRank.append(rankSum)

# %% [markdown]
# # The Final Ranking

# %%
index = []
rank = [[]]
for i in range(90) :  
    index.append(i)
    
    rank[i].append(n[i])
    rank[i].append(nRank[i])
    
    rank.insert(i+1, [])
    
del rank[90]
    
rank = pd.DataFrame(rank,
                      columns = ['Neighborhood', 'Rank'], index=index)

rank = rank.sort_values('Rank')
rank.plot.bar(x='Neighborhood', figsize=(20,8))
# Out:
# <AxesSubplot:xlabel='Neighborhood'>

# %% [markdown]
# ## Squirrel Hill South wins! And here's our top ten:

# %%
rank.head(10)
# Out:
#            Neighborhood  Rank
# 76  Squirrel Hill South     4
# 39        Highland Park     8
# 75  Squirrel Hill North    12
# 62         Point Breeze    18
# 67            Shadyside    21
# 0      Allegheny Center    24
# 60          Perry North    30
# 78      Stanton Heights    36
# 9            Bloomfield    36
# 13            Brookline    43

# %%
rank.head(10).plot.bar(x="Neighborhood")
# Out:
# <AxesSubplot:xlabel='Neighborhood'>

# %%
#For importing into final.ipynb

rankList = []
for r in range(90) :
    rankList.append(0)
    
i = rank.index.tolist()
for r in range(90) :
    rankList[i[r]] = (r+1)

scoresList = [[]]
for i in range(90) :      
    scoresList[i].append(n[i])
    scoresList[i].append(rankList[i])
    
    scoresList.insert(i+1, [])
    
del scoresList[90]

finalRank = pd.DataFrame(scoresList, columns=['Neighborhood', 'Rank']).sort_values("Rank")
finalRank.head(10)
# Out:
#            Neighborhood  Rank
# 76  Squirrel Hill South     1
# 39        Highland Park     2
# 75  Squirrel Hill North     3
# 62         Point Breeze     4
# 67            Shadyside     5
# 0      Allegheny Center     6
# 60          Perry North     7
# 78      Stanton Heights     8
# 9            Bloomfield     9
# 13            Brookline    10
